# %% [markdown]
# <a href="https://colab.research.google.com/github/yuYuul/Programaci-n-II-Grupo-E/blob/main/EstadisticaPacientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import  files
#subir archivo desde tu computadora
uploaded=files.upload()
# Out:
#      <input type="file" id="files-52cfa6e4-0abd-4e6e-a21d-6dfc1da4ac86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52cfa6e4-0abd-4e6e-a21d-6dfc1da4ac86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
#Leer archivo separado por "|"
df=pd.read_csv("pacienteInforme.txt", sep="|",header=None)
#Nombrar columnas
df.columns=["Nombre", "Fecha de Nacimiento", "Edad", "Sexo", "Grupo Sanguineo", "Seguro", "Hospital", "Peso"]
#ver primeros registros
df.head()
# Out:
#                 Nombre Fecha de Nacimiento       Edad         Sexo  \
# 0       Valeria Gómez          12/03/1990    35 años     Femenino
# 1  Andrés Salvatierra          25/07/1985    40 años    Masculino
# 2        Carla Méndez          08/11/1998    26 años     Femenino
# 3       Rodrigo Pérez          30/01/1975    50 años    Masculino
#
#   Grupo Sanguineo                 Seguro                         Hospital  \
# 0             O+        Seguros VidaBol              Clínica Santa María
# 1             A-            Salud Total    Hospital Universitario La Paz
# 2             B+     Mediseguro Bolivia          Centro Médico Los Andes
# 3            AB-    Bolivian HealthCare           Hospital Metropolitano
#
#    Peso
# 0    70
# 1    67
# 2    58
# 3    82
